# %% [markdown]
# # Iris Flowers Classification ML Project :
# The Iris Flowers Classification ML project is a machine learning project focused on accurately categorizing iris flower species based on their measurements. By employing various classification algorithms, it aims to develop a robust model capable of predicting the correct species of iris flowers with a high degree of accuracy.
#
# **1**.import dataset
#
# **2**.visualizing the dataset
#
# **3**.Data preparation
#
# **4**.Training the algorithm
#
# **5**.Making Perdiction.
#
#  **6**.Model Evolution
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# #1. Importing Dataset

# %%
df=pd.read_csv('/content/iris.csv')
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.head(10)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
df.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
data=df.groupby('variety')

# %%
data.head()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 0             5.1          3.5           1.4          0.2      Setosa
# 1             4.9          3.0           1.4          0.2      Setosa
# 2             4.7          3.2           1.3          0.2      Setosa
# 3             4.6          3.1           1.5          0.2      Setosa
# 4             5.0          3.6           1.4          0.2      Setosa
# 50            7.0          3.2           4.7          1.4  Versicolor
# 51            6.4          3.2           4.5          1.5  Versicolor
# 52            6.9          3.1           4.9          1.5  Versicolor
# 53            5.5          2.3           4.0          1.3  Versicolor
# 54            6.5          2.8           4.6          1.5  Versicolor
# 100           6.3          3.3           6.0          2.5   Virginica
# 101           5.8          2.7           5.1          1.9   Virginica
# ...

# %%
df['variety'].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width     variety
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.057333      3.758000     1.199333    2.000000
# std        0.828066     0.435866      1.765298     0.762238    0.819232
# min        4.300000     2.000000      1.000000     0.100000    1.000000
# 25%        5.100000     2.800000      1.600000     0.300000    1.000000
# 50%        5.800000     3.000000      4.350000     1.300000    2.000000
# 75%        6.400000     3.300000      5.100000     1.800000    3.000000
# max        7.900000     4.400000      6.900000     2.500000    3.000000

# %% [markdown]
# # 2. visualizing the dataset

# %%
plt.boxplot(df['sepal.length'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fceffb80100>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fceffb82740>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fceffb801c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fceffb82cb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fceffb82f80>],
#  'means': []}

# %%
plt.boxplot(df['sepal.width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcefcc52320>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fcefcc52860>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcefcc52080>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcefcc52da0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcefcc53040>],
#  'means': []}

# %%
plt.boxplot(df['petal.length'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcefccd51e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fcefccd5720>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcefccd4f40>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcefccd5c60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcefccd5f00>],
#  'means': []}

# %%
plt.boxplot(df['petal.width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcefcb54460>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fcefcb549a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcefcb541c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcefcb54ee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcefcb55180>],
#  'means': []}

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-19-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df['sepal.length'].hist()
# Out:
# <Axes: >

# %%
df['sepal.width'].hist()
# Out:
# <Axes: >

# %%
df['petal.length'].hist()
# Out:
# <Axes: >

# %%
df['petal.width'].hist()
# Out:
# <Axes: >

# %%
sns.catplot(x='variety', hue='variety', kind='count',data=df)

# %%
plt.bar(df['variety'],df['petal.width'])
# Out:
# <BarContainer object of 150 artists>

# %%
sns.pairplot(df, hue='variety')

# %% [markdown]
# # 3. Data Preparation

# %%
sp={'Setosa':1,'Versicolor':2,'Virginica':3}

# %%
df.variety=[sp[i] for i in df.variety]

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0             5.1          3.5           1.4          0.2        1
# 1             4.9          3.0           1.4          0.2        1
# 2             4.7          3.2           1.3          0.2        1
# 3             4.6          3.1           1.5          0.2        1
# 4             5.0          3.6           1.4          0.2        1
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        3
# 146           6.3          2.5           5.0          1.9        3
# 147           6.5          3.0           5.2          2.0        3
# 148           6.2          3.4           5.4          2.3        3
# 149           5.9          3.0           5.1          1.8        3
#
# [150 rows x 5 columns]

# %%
X=df.iloc[:,0:4]

# %%
X
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y=df.iloc[:,4]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    3
# 146    3
# 147    3
# 148    3
# 149    3
# Name: variety, Length: 150, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %% [markdown]
# # Traning Model

# %%
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.score(X,y)
# Out:
# 0.9303939218549564

# %%
model.coef_
# Out:
# array([-0.11190585, -0.04007949,  0.22864503,  0.60925205])

# %%
model.intercept_
# Out:
# 1.1864952472062478

# %% [markdown]
# # Making Predictions

# %%
y_pred=model.predict(X_test)

# %% [markdown]
# # Model Evolution

# %%
print("Mean squared error: %.2f" % np.mean((y_pred - y_test) ** 2))
# Out:
# Mean squared error: 0.04
